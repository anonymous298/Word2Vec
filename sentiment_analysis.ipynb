# %%
import pandas as pd
import numpy as np
import re

from nltk.stem import WordNetLemmatizer
from gensim.utils import simple_preprocess

# %%
df = pd.read_csv('data/IMDB Dataset.csv')

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.shape
# Out:
# (50000, 2)

# %%
def preprocess_text(data):
    text = re.sub(r'[^a-zA-Z]', ' ', data)
    tokens = [word.lower() for word in text.split()]
    clean_text = ' '.join(tokens)
    return clean_text

# %%
df['review'] = df['review'].apply(preprocess_text)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production br br the filmin...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there s a family where a little boy ...  negative
# 4  petter mattei s love in the time of money is a...  positive

# %%
def df_to_corpus(df):
    corpus = []
    for i in range(df.shape[0]):
        text = df['review'][i]
        corpus.append(simple_preprocess(text))

    return corpus

# %%
corpus = df_to_corpus(df=df)

# %%
len(corpus)
# Out:
# 50000

# %%
from gensim.models import Word2Vec

# %%
w2v = Word2Vec(corpus, vector_size=150, epochs=50)

# %%
w2v.corpus_count
# Out:
# 50000

# %%
w2v.wv.key_to_index
# Out:
# {'the': 0,
#  'and': 1,
#  'of': 2,
#  'to': 3,
#  'is': 4,
#  'br': 5,
#  'it': 6,
#  'in': 7,
#  'this': 8,
#  'that': 9,
#  'was': 10,
#  'as': 11,
#  'movie': 12,
#  'for': 13,
#  'with': 14,
#  'but': 15,
#  'film': 16,
#  'you': 17,
#  'on': 18,
#  'not': 19,
#  'he': 20,
#  'are': 21,
#  'his': 22,
#  'have': 23,
#  'one': 24,
#  'be': 25,
#  'all': 26,
#  'at': 27,
#  'they': 28,
#  'by': 29,
#  'an': 30,
#  'who': 31,
#  'so': 32,
#  'from': 33,
#  'like': 34,
#  'there': 35,
#  'or': 36,
#  'just': 37,
#  'her': 38,
#  'out': 39,
#  'about': 40,
#  'if': 41,
#  'has': 42,
#  'what': 43,
#  'some': 44,
#  'good': 45,
#  'can': 46,
#  'when': 47,
#  'more': 48,
#  'very': 49,
#  'she': 50,
#  'up': 51,
#  'no': 52,
#  'time': 53,
#  'my': 54,
#  'even': 55,
#  'would': 56,
#  'which': 57,
#  'only': 58,
#  'story': 59,
#  'really': 60,
#  'see': 61,
#  'their': 62,
#  'had': 63,
#  'me': 64,
#  'well': 65,
#  'we': 66,
#  'were': 67,
#  'than': 68,
#  'much': 69,
#  'bad': 70,
#  'get': 71,
#  'been': 72,
#  'other': 73,
#  'do': 74,
#  'people': 75,
#  'great': 76,
#  'will': 77,
#  'also': 78,
#  'into': 79,
#  'because': 80,
#  'how': 81,
#  'don': 82,
#  'him': 83,
#  'first': 84,
#  'most': 85,
#  'made': 86,
#  'its': 87,
#  'them': 88,
#  'then': 89,
#  'make': 90,
#  'way': 91,
#  'could': 92,
#  'too': 93,
#  'movies': 94,
#  'any': 95,
#  'after': 96,
#  'characters': 97,
#  'think': 98,
#  'watch': 99,
#  'character': 100,
#  'films': 101,
#  'two': 102,
#  'many': 103,
#  'seen': 104,
#  'being': 105,
#  'love': 106,
#  'plot': 107,
#  'never': 108,
#  'life': 109,
#  'acting': 110,
#  'where': 111,
#  'show': 112,
#  'did': 113,
#  'best': 114,
#  'know': 115,
#  'little': 116,
#  'over': 117,
#  'off': 118,
#  'ever': 119,
#  'man': 120,
#  'does': 121,
#  'your': 122,
#  'better': 123,
#  'end': 124,
#  'here': 125,
#  'scene': 126,
#  'still': 127,
#  'say': 128,
#  'these': 129,
#  'why': 130,
#  'scenes': 131,
#  'while': 132,
#  've': 133,
#  'something': 134,
#  'such': 135,
#  'go': 136,
#  'should': 137,
#  'through': 138,
#  'back': 139,
#  'real': 140,
#  'those': 141,
#  'now': 142,
#  'thing': 143,
#  'watching': 144,
#  're': 145,
#  'actors': 146,
#  'doesn': 147,
#  'director': 148,
#  'didn': 149,
#  'years': 150,
#  'funny': 151,
#  'though': 152,
#  'old': 153,
#  'another': 154,
#  'work': 155,
#  'before': 156,
#  'actually': 157,
#  'nothing': 158,
#  'makes': 159,
#  'look': 160,
#  'find': 161,
#  'going': 162,
#  'new': 163,
#  'same': 164,
#  'lot': 165,
#  'every': 166,
#  'few': 167,
#  'again': 168,
#  'part': 169,
#  'world': 170,
#  'down': 171,
#  'cast': 172,
#  'us': 173,
#  'things': 174,
#  'want': 175,
#  'quite': 176,
#  'pretty': 177,
#  'horror': 178,
#  'around': 179,
#  'seems': 180,
#  'young': 181,
#  'take': 182,
#  'big': 183,
#  'however': 184,
#  'got': 185,
#  'thought': 186,
#  'fact': 187,
#  'enough': 188,
#  'long': 189,
#  'both': 190,
#  'give': 191,
#  'may': 192,
#  'own': 193,
#  'between': 194,
#  'comedy': 195,
#  'series': 196,
#  'must': 197,
#  'right': 198,
#  'action': 199,
#  'music': 200,
#  'without': 201,
#  'guy': 202,
#  'times': 203,
#  'saw': 204,
#  'original': 205,
#  'always': 206,
#  'isn': 207,
#  'role': 208,
#  'come': 209,
#  'almost': 210,
#  'gets': 211,
#  'point': 212,
#  'interesting': 213,
#  'done': 214,
#  'whole': 215,
#  'least': 216,
#  'far': 217,
#  'bit': 218,
#  'script': 219,
#  'family': 220,
#  'minutes': 221,
#  'feel': 222,
#  'll': 223,
#  'am': 224,
#  'might': 225,
#  'making': 226,
#  'anything': 227,
#  'since': 228,
#  'tv': 229,
#  'last': 230,
#  'probably': 231,
#  'performance': 232,
#  'kind': 233,
#  'away': 234,
#  'girl': 235,
#  'yet': 236,
#  'fun': 237,
#  'anyone': 238,
#  'woman': 239,
#  'worst': 240,
#  'sure': 241,
#  'rather': 242,
#  'hard': 243,
#  'day': 244,
#  'each': 245,
#  'played': 246,
#  'found': 247,
#  'looking': 248,
#  'screen': 249,
#  'our': 250,
#  'although': 251,
#  'especially': 252,
#  'believe': 253,
#  'dvd': 254,
#  'having': 255,
#  'trying': 256,
#  'course': 257,
#  'everything': 258,
#  'set': 259,
#  'goes': 260,
#  'book': 261,
#  'ending': 262,
#  'put': 263,
#  'comes': 264,
#  'maybe': 265,
#  'place': 266,
#  'let': 267,
#  'shows': 268,
#  'three': 269,
#  'worth': 270,
#  'different': 271,
#  'actor': 272,
#  'once': 273,
#  'main': 274,
#  'sense': 275,
#  'someone': 276,
#  'american': 277,
#  'reason': 278,
#  'play': 279,
#  'effects': 280,
#  'looks': 281,
#  'true': 282,
#  'money': 283,
#  'watched': 284,
#  'wasn': 285,
#  'year': 286,
#  'everyone': 287,
#  'job': 288,
#  'together': 289,
#  'war': 290,
#  'high': 291,
#  'plays': 292,
#  'audience': 293,
#  'instead': 294,
#  'during': 295,
#  'half': 296,
#  'said': 297,
#  'later': 298,
#  'takes': 299,
#  'special': 300,
#  'john': 301,
#  'night': 302,
#  'seem': 303,
#  'beautiful': 304,
#  'left': 305,
#  'black': 306,
#  'himself': 307,
#  'seeing': 308,
#  'wife': 309,
#  'version': 310,
#  'shot': 311,
#  'excellent': 312,
#  'house': 313,
#  'idea': 314,
#  'star': 315,
#  'else': 316,
#  'mind': 317,
#  'death': 318,
#  'fan': 319,
#  'father': 320,
#  'used': 321,
#  'nice': 322,
#  'budget': 323,
#  'simply': 324,
#  'poor': 325,
#  'short': 326,
#  'completely': 327,
#  'second': 328,
#  'men': 329,
#  'read': 330,
#  'less': 331,
#  'along': 332,
#  'top': 333,
#  'home': 334,
#  'dead': 335,
#  'help': 336,
#  'line': 337,
#  'hollywood': 338,
#  'either': 339,
#  'kids': 340,
#  'boring': 341,
#  'friends': 342,
#  'camera': 343,
#  'production': 344,
#  'try': 345,
#  'wrong': 346,
#  'enjoy': 347,
#  'classic': 348,
#  'low': 349,
#  'use': 350,
#  'given': 351,
#  'women': 352,
#  'full': 353,
#  'need': 354,
#  'school': 355,
#  'stupid': 356,
#  'next': 357,
#  'until': 358,
#  'performances': 359,
#  'rest': 360,
#  'truly': 361,
#  'couple': 362,
#  'video': 363,
#  'awful': 364,
#  'sex': 365,
#  'start': 366,
#  'recommend': 367,
#  'tell': 368,
#  'terrible': 369,
#  'mean': 370,
#  'remember': 371,
#  'getting': 372,
#  'won': 373,
#  'came': 374,
#  'understand': 375,
#  'perhaps': 376,
#  'name': 377,
#  'moments': 378,
#  'face': 379,
#  'person': 380,
#  'keep': 381,
#  'itself': 382,
#  'human': 383,
#  'wonderful': 384,
#  'mother': 385,
#  'playing': 386,
#  'style': 387,
#  'episode': 388,
#  'small': 389,
#  'others': 390,
#  'boy': 391,
#  'perfect': 392,
#  'stars': 393,
#  'early': 394,
#  'doing': 395,
#  'head': 396,
#  'often': 397,
#  'written': 398,
#  'definitely': 399,
#  'lines': 400,
#  'children': 401,
#  'dialogue': 402,
#  'gives': 403,
#  'piece': 404,
#  'couldn': 405,
#  'went': 406,
#  'finally': 407,
#  'case': 408,
#  'yes': 409,
#  'title': 410,
#  'absolutely': 411,
#  'live': 412,
#  'laugh': 413,
#  'oh': 414,
#  'certainly': 415,
#  'friend': 416,
#  'lost': 417,
#  'liked': 418,
#  'become': 419,
#  'entertaining': 420,
#  'worse': 421,
#  'sort': 422,
#  'cinema': 423,
#  'picture': 424,
#  'loved': 425,
#  'hope': 426,
#  'called': 427,
#  'felt': 428,
#  'mr': 429,
#  'overall': 430,
#  'guys': 431,
#  'based': 432,
#  'entire': 433,
#  'several': 434,
#  'supposed': 435,
#  'drama': 436,
#  'sound': 437,
#  'problem': 438,
#  'white': 439,
#  'against': 440,
#  'waste': 441,
#  'beginning': 442,
#  'dark': 443,
#  'fans': 444,
#  'game': 445,
#  'totally': 446,
#  'care': 447,
#  'humor': 448,
#  'direction': 449,
#  'wanted': 450,
#  'under': 451,
#  'seemed': 452,
#  'evil': 453,
#  'lives': 454,
#  'lead': 455,
#  'despite': 456,
#  'guess': 457,
#  'final': 458,
#  'example': 459,
#  'already': 460,
#  'turn': 461,
#  'throughout': 462,
#  'becomes': 463,
#  'killer': 464,
#  'unfortunately': 465,
#  'able': 466,
#  'son': 467,
#  'quality': 468,
#  'days': 469,
#  'history': 470,
#  'heart': 471,
#  'side': 472,
#  'fine': 473,
#  'michael': 474,
#  'flick': 475,
#  'wants': 476,
#  'writing': 477,
#  'horrible': 478,
#  'amazing': 479,
#  'run': 480,
#  'today': 481,
#  'art': 482,
#  'town': 483,
#  'act': 484,
#  'works': 485,
#  'close': 486,
#  'kill': 487,
#  'god': 488,
#  'child': 489,
#  'matter': 490,
#  'etc': 491,
#  'tries': 492,
#  'viewer': 493,
#  'past': 494,
#  'genre': 495,
#  'enjoyed': 496,
#  'turns': 497,
#  'brilliant': 498,
#  'gave': 499,
#  'behind': 500,
#  'car': 501,
#  'stuff': 502,
#  'eyes': 503,
#  'parts': 504,
#  'favorite': 505,
#  'girls': 506,
#  'directed': 507,
#  'hand': 508,
#  'kid': 509,
#  'late': 510,
#  'city': 511,
#  'hour': 512,
#  'expect': 513,
#  'soon': 514,
#  'actress': 515,
#  'obviously': 516,
#  'themselves': 517,
#  'sometimes': 518,
#  'thinking': 519,
#  'killed': 520,
#  'myself': 521,
#  'starts': 522,
#  'decent': 523,
#  'stop': 524,
#  'type': 525,
#  'self': 526,
#  'daughter': 527,
#  'highly': 528,
#  'group': 529,
#  'says': 530,
#  'blood': 531,
#  'voice': 532,
#  'anyway': 533,
#  'writer': 534,
#  'known': 535,
#  'took': 536,
#  'heard': 537,
#  'happens': 538,
#  'except': 539,
#  'fight': 540,
#  'feeling': 541,
#  'experience': 542,
#  'coming': 543,
#  'slow': 544,
#  'moment': 545,
#  'stories': 546,
#  'leave': 547,
#  'police': 548,
#  'told': 549,
#  'extremely': 550,
#  'score': 551,
#  'violence': 552,
#  'hero': 553,
#  'involved': 554,
#  'strong': 555,
#  'chance': 556,
#  'lack': 557,
#  'ok': 558,
#  'hit': 559,
#  'hilarious': 560,
#  'cannot': 561,
#  'happen': 562,
#  'wouldn': 563,
#  'roles': 564,
#  'wonder': 565,
#  'living': 566,
#  'particularly': 567,
#  'including': 568,
#  'hell': 569,
#  'save': 570,
#  'brother': 571,
#  'crap': 572,
#  'murder': 573,
#  'looked': 574,
#  'cool': 575,
#  'david': 576,
#  'please': 577,
#  'simple': 578,
#  'age': 579,
#  'cut': 580,
#  'obvious': 581,
#  'complete': 582,
#  'song': 583,
#  'gore': 584,
#  'happened': 585,
#  'serious': 586,
#  'james': 587,
#  'attempt': 588,
#  'ago': 589,
#  'shown': 590,
#  'taken': 591,
#  'robert': 592,
#  'english': 593,
#  'husband': 594,
#  'reality': 595,
#  'seriously': 596,
#  'released': 597,
#  'jokes': 598,
#  'opening': 599,
#  'interest': 600,
#  'none': 601,
#  'alone': 602,
#  'across': 603,
#  'sad': 604,
#  'possible': 605,
#  'exactly': 606,
#  'career': 607,
#  'hours': 608,
#  'number': 609,
#  'saying': 610,
#  'usually': 611,
#  'cinematography': 612,
#  'talent': 613,
#  'view': 614,
#  'documentary': 615,
#  'relationship': 616,
#  'annoying': 617,
#  'yourself': 618,
#  'running': 619,
#  'wish': 620,
#  'order': 621,
#  'huge': 622,
#  'whose': 623,
#  'shots': 624,
#  'body': 625,
#  'light': 626,
#  'taking': 627,
#  'ridiculous': 628,
#  'country': 629,
#  'power': 630,
#  'important': 631,
#  'middle': 632,
#  'call': 633,
#  'level': 634,
#  'female': 635,
#  'ends': 636,
#  'major': 637,
#  'started': 638,
#  'four': 639,
#  'word': 640,
#  'jack': 641,
#  'turned': 642,
#  'opinion': 643,
#  'scary': 644,
#  'change': 645,
#  'mostly': 646,
#  'usual': 647,
#  'beyond': 648,
#  'happy': 649,
#  'room': 650,
#  'ones': 651,
#  'silly': 652,
#  'rating': 653,
#  'somewhat': 654,
#  'novel': 655,
#  'words': 656,
#  'talking': 657,
#  'knows': 658,
#  'knew': 659,
#  'disappointed': 660,
#  'strange': 661,
#  'non': 662,
#  'apparently': 663,
#  'modern': 664,
#  'upon': 665,
#  'attention': 666,
#  'single': 667,
#  'finds': 668,
#  'basically': 669,
#  'cheap': 670,
#  'television': 671,
#  'due': 672,
#  'musical': 673,
#  'earth': 674,
#  'problems': 675,
#  'miss': 676,
#  'clich': 677,
#  'episodes': 678,
#  'clearly': 679,
#  'local': 680,
#  'thriller': 681,
#  'king': 682,
#  'five': 683,
#  'british': 684,
#  'talk': 685,
#  'events': 686,
#  'class': 687,
#  'sequence': 688,
#  'aren': 689,
#  'team': 690,
#  'french': 691,
#  'moving': 692,
#  'fast': 693,
#  'ten': 694,
#  'review': 695,
#  'tells': 696,
#  'straight': 697,
#  'predictable': 698,
#  'die': 699,
#  'comic': 700,
#  'entertainment': 701,
#  'songs': 702,
#  'space': 703,
#  'whether': 704,
#  'george': 705,
#  'future': 706,
#  'dialog': 707,
#  'add': 708,
#  'above': 709,
#  'sets': 710,
#  'easily': 711,
#  'enjoyable': 712,
#  'near': 713,
#  'appears': 714,
#  'haven': 715,
#  'soundtrack': 716,
#  'hate': 717,
#  'bring': 718,
#  'romantic': 719,
#  'lots': 720,
#  'giving': 721,
#  'similar': 722,
#  'supporting': 723,
#  'message': 724,
#  'release': 725,
#  'mention': 726,
#  'eye': 727,
#  'within': 728,
#  'filmed': 729,
#  'sequel': 730,
#  'falls': 731,
#  'rock': 732,
#  'sister': 733,
#  'monster': 734,
#  'clear': 735,
#  'needs': 736,
#  'dull': 737,
#  'bunch': 738,
#  'suspense': 739,
#  'surprised': 740,
#  'showing': 741,
#  'easy': 742,
#  'sorry': 743,
#  'tried': 744,
#  'certain': 745,
#  'ways': 746,
#  'working': 747,
#  'theme': 748,
#  'theater': 749,
#  'parents': 750,
#  'among': 751,
#  'named': 752,
#  'storyline': 753,
#  'lady': 754,
#  'stay': 755,
#  'fall': 756,
#  'effort': 757,
#  'stand': 758,
#  'minute': 759,
#  'gone': 760,
#  'feature': 761,
#  'dr': 762,
#  'buy': 763,
#  'tale': 764,
#  'dog': 765,
#  'using': 766,
#  'typical': 767,
#  'comments': 768,
#  'th': 769,
#  'mystery': 770,
#  'editing': 771,
#  'subject': 772,
#  'avoid': 773,
#  'oscar': 774,
#  'deal': 775,
#  'doubt': 776,
#  'richard': 777,
#  'fantastic': 778,
#  'peter': 779,
#  'okay': 780,
#  'feels': 781,
#  'realistic': 782,
#  'viewers': 783,
#  'kept': 784,
#  'nearly': 785,
#  'general': 786,
#  'check': 787,
#  'viewing': 788,
#  'elements': 789,
#  'points': 790,
#  'greatest': 791,
#  'herself': 792,
#  'means': 793,
#  'famous': 794,
#  'crime': 795,
#  'rent': 796,
#  'imagine': 797,
#  'paul': 798,
#  'red': 799,
#  'actual': 800,
#  'form': 801,
#  'follow': 802,
#  'period': 803,
#  'material': 804,
#  'believable': 805,
#  'tom': 806,
#  'move': 807,
#  'brought': 808,
#  'forget': 809,
#  'somehow': 810,
#  'begins': 811,
#  'animation': 812,
#  'reviews': 813,
#  'leads': 814,
#  'doctor': 815,
#  'imdb': 816,
#  'surprise': 817,
#  'figure': 818,
#  'america': 819,
#  'weak': 820,
#  'hear': 821,
#  'average': 822,
#  'sit': 823,
#  'open': 824,
#  'york': 825,
#  'deep': 826,
#  'fi': 827,
#  'sequences': 828,
#  'killing': 829,
#  'atmosphere': 830,
#  'wait': 831,
#  'learn': 832,
#  'eventually': 833,
#  'premise': 834,
#  'sci': 835,
#  'whatever': 836,
#  'expected': 837,
#  'dance': 838,
#  'lame': 839,
#  'boys': 840,
#  'indeed': 841,
#  'poorly': 842,
#  'note': 843,
#  'particular': 844,
#  'box': 845,
#  'truth': 846,
#  'situation': 847,
#  'hot': 848,
#  'third': 849,
#  'shame': 850,
#  'society': 851,
#  'season': 852,
#  'free': 853,
#  'decided': 854,
#  'difficult': 855,
#  'romance': 856,
#  'lee': 857,
#  'needed': 858,
#  'acted': 859,
#  'crew': 860,
#  'leaves': 861,
#  'gay': 862,
#  'sexual': 863,
#  'emotional': 864,
#  'western': 865,
#  'unless': 866,
#  'possibly': 867,
#  'footage': 868,
#  'de': 869,
#  'credits': 870,
#  'write': 871,
#  'forced': 872,
#  'memorable': 873,
#  'became': 874,
#  'reading': 875,
#  'begin': 876,
#  'air': 877,
#  'meet': 878,
#  'otherwise': 879,
#  'question': 880,
#  'male': 881,
#  'street': 882,
#  'nature': 883,
#  'meets': 884,
#  'beauty': 885,
#  'hands': 886,
#  'plus': 887,
#  'cheesy': 888,
#  'screenplay': 889,
#  'masterpiece': 890,
#  'superb': 891,
#  'features': 892,
#  'effect': 893,
#  'stage': 894,
#  'interested': 895,
#  'island': 896,
#  'perfectly': 897,
#  'whom': 898,
#  'laughs': 899,
#  'comment': 900,
#  'forward': 901,
#  'cop': 902,
#  'weird': 903,
#  'badly': 904,
#  'nor': 905,
#  'inside': 906,
#  'japanese': 907,
#  'sounds': 908,
#  'previous': 909,
#  'personal': 910,
#  'quickly': 911,
#  'total': 912,
#  'crazy': 913,
#  'baby': 914,
#  'mark': 915,
#  'girlfriend': 916,
#  'keeps': 917,
#  'disney': 918,
#  'result': 919,
#  'towards': 920,
#  'writers': 921,
#  'battle': 922,
#  'fire': 923,
#  'joe': 924,
#  'setting': 925,
#  'worked': 926,
#  'background': 927,
#  'incredibly': 928,
#  'earlier': 929,
#  'mess': 930,
#  'copy': 931,
#  'dumb': 932,
#  'business': 933,
#  'unique': 934,
#  'bill': 935,
#  'directors': 936,
#  'realize': 937,
#  'powerful': 938,
#  'water': 939,
#  'dramatic': 940,
#  'older': 941,
#  'rate': 942,
#  'joke': 943,
#  'dream': 944,
#  'following': 945,
#  'pay': 946,
#  'plenty': 947,
#  'directing': 948,
#  'ask': 949,
#  'various': 950,
#  'creepy': 951,
#  'development': 952,
#  'appear': 953,
#  'front': 954,
#  'brings': 955,
#  'rich': 956,
#  'admit': 957,
#  'political': 958,
#  'apart': 959,
#  'cover': 960,
#  'fairly': 961,
#  'leading': 962,
#  'spent': 963,
#  'reasons': 964,
#  'portrayed': 965,
#  'era': 966,
#  'gun': 967,
#  'outside': 968,
#  'present': 969,
#  'telling': 970,
#  'party': 971,
#  'wasted': 972,
#  'zombie': 973,
#  'fighting': 974,
#  'william': 975,
#  'deserves': 976,
#  'fails': 977,
#  'success': 978,
#  'break': 979,
#  'twist': 980,
#  'list': 981,
#  'secret': 982,
#  'meant': 983,
#  'return': 984,
#  'create': 985,
#  'expecting': 986,
#  'missing': 987,
#  'attempts': 988,
#  'ideas': 989,
#  'ended': 990,
#  'manages': 991,
#  'cute': 992,
#  'recently': 993,
#  'agree': 994,
#  'villain': 995,
#  'german': 996,
#  'fantasy': 997,
#  'match': 998,
#  'talented': 999,
#  ...}

# %%
def avg_word2vec(tokens):
    word_embeddings = [w2v.wv[word] for word in tokens if word in w2v.wv.index_to_key]
    avg = np.mean(word_embeddings, axis=0)

    return avg if word_embeddings else np.zeros(w2v.vector_size)

# %%
from tqdm import tqdm

# %%
final_embeddings = []
for i in tqdm(range(len(corpus))):
    final_embeddings.append(avg_word2vec(corpus[i]))
# Out:
# 100%|██████████| 50000/50000 [16:29<00:00, 50.53it/s]

# %%
X = np.array(final_embeddings)
y = df['sentiment'].map({'positive' : 1, 'negative' : 0})

# %%
X.shape
# Out:
# (50000, 150)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import recall_score, precision_score, accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
models = {
    'lor' : LogisticRegression(),
    'svc' : SVC(),
    'rf' : RandomForestClassifier()
}

for name,mod in models.items():
    model = mod
    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    print('=' * 50)
    print(name)
    print('Training Evaluation')
    print('-' * 50)

    print(precision_score(y_train, y_pred_train))
    print(recall_score(y_train, y_pred_train))
    print(accuracy_score(y_train, y_pred_train))

    print('-' * 50)
    print('Testing Evaluation')
    print('-' * 50)

    print(precision_score(y_test, y_pred_test))
    print(recall_score(y_test, y_pred_test))
    print(accuracy_score(y_test, y_pred_test))
# Out:
# ==================================================
# lor
# Training Evaluation
# --------------------------------------------------
# 0.8721688400823611
# 0.8758256274768824
# 0.8743714285714286
# --------------------------------------------------
# Testing Evaluation
# --------------------------------------------------
# 0.8760537407797682
# 0.8764000527078667
# 0.8747333333333334
# ==================================================
# svc
# Training Evaluation
# --------------------------------------------------
# 0.8883411670296916
# 0.890126931250359
# 0.8896857142857143
# --------------------------------------------------
# Testing Evaluation
# --------------------------------------------------
# 0.8788990825688073
# 0.8836473843721175
# 0.8795333333333333
# ==================================================
# rf
# Training Evaluation
# --------------------------------------------------
# 1.0
# 1.0
# 1.0
# --------------------------------------------------
# Testing Evaluation
# --------------------------------------------------
# 0.8272339324970904
# 0.8429305573856898
# 0.8314666666666667

# %% [markdown]
# # **Creating Neural Network Architecture**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),

    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\TALHA PC\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_42 (Dense)                │ (None, 128)            │        19,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,457 (76.00 KB)
#  Trainable params: 19,457 (76.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tb_callback = TensorBoard(log_dir='log/', histogram_freq=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, callbacks=[tb_callback, early_stopping])
# Out:
# Epoch 1/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7969 - loss: 0.4272 - val_accuracy: 0.8671 - val_loss: 0.3113
# Epoch 2/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8676 - loss: 0.3130 - val_accuracy: 0.8694 - val_loss: 0.3065
# Epoch 3/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8724 - loss: 0.3056 - val_accuracy: 0.8719 - val_loss: 0.3022
# Epoch 4/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8741 - loss: 0.3018 - val_accuracy: 0.8729 - val_loss: 0.3008
# Epoch 5/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8784 - loss: 0.2903 - val_accuracy: 0.8770 - val_loss: 0.2951
# Epoch 6/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8780 - loss: 0.2904 - val_accuracy: 0.8756 - val_loss: 0.2918
# Epoch 7/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8776 - loss: 0.2928 - val_accuracy: 0.8746 - val_loss: 0.2981
# Epoch 8/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8800 - loss: 0.2841 - val_accuracy: 0.8779 - val_loss: 0.2923
# Epoch 9/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8796 - loss: 0.2848 - val_accuracy: 0.8726 - val_loss: 0.3001
# Epoch 10/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8840 - loss: 0.2764 - val_accuracy: 0.8790 - val_loss: 0.2890
# Epoch 11/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8848 - loss: 0.2779 - val_accuracy: 0.8713 - val_loss: 0.3046
# Epoch 12/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8862 - loss: 0.2772 - val_accuracy: 0.8783 - val_loss: 0.2916
# Epoch 13/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8857 - loss: 0.2735 - val_accuracy: 0.8797 - val_loss: 0.2886
# Epoch 14/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8886 - loss: 0.2684 - val_accuracy: 0.8705 - val_loss: 0.3060
# Epoch 15/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8893 - loss: 0.2720 - val_accuracy: 0.8783 - val_loss: 0.2920
# Epoch 16/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8910 - loss: 0.2632 - val_accuracy: 0.8778 - val_loss: 0.2914
# Epoch 17/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8899 - loss: 0.2630 - val_accuracy: 0.8783 - val_loss: 0.2912
# Epoch 18/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8911 - loss: 0.2630 - val_accuracy: 0.8803 - val_loss: 0.2942
# Epoch 19/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8904 - loss: 0.2638 - val_accuracy: 0.8785 - val_loss: 0.2995
# Epoch 20/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8908 - loss: 0.2603 - val_accuracy: 0.8775 - val_loss: 0.2991
# Epoch 21/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8912 - loss: 0.2611 - val_accuracy: 0.8769 - val_loss: 0.2993
# Epoch 22/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8960 - loss: 0.2513 - val_accuracy: 0.8792 - val_loss: 0.2981
# Epoch 23/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8947 - loss: 0.2519 - val_accuracy: 0.8767 - val_loss: 0.2961

# %%
text = 'I appreciate the movie hard work'

# %%
text = preprocess_text(text)

# %%
tokens = simple_preprocess(text)

# %%
avg_embedding = avg_word2vec(tokens)

# %%
prediction = model.predict(avg_embedding.reshape(1,-1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
def class_returner(prediciton):
    if prediciton >= 0.6:
        print('Positive')

    elif prediciton < 0.4:
        print('Negative')

    else:
        print('Neutral')

# %%
class_returner(prediction)
# Out:
# Positive

# %%
model.save('models/model_file.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
